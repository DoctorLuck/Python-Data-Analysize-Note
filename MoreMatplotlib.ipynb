# %%
import matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,10)

# %%
x
# Out:
# array([ 0.        ,  0.55555556,  1.11111111,  1.66666667,  2.22222222,
#         2.77777778,  3.33333333,  3.88888889,  4.44444444,  5.        ])

# %%
y = x ** 2

# %%
# %matplotlib inline

# %%
import matplotlib.pylab as plb

# %%
plt.figure??

# %%
plt.plot(x,y,'g')
# 此处的第三个参数用于指明颜色
plt.xlabel('x')
plt.ylabel('y')
plt.title('First Test')
plt.show()

# %%
plb.subplot(1,2,1)
# subplot的作用是将多个图画在同一个窗口中，第一个参数指行数 第二个为列数 第三个是指明第几个
plt.plot(x,y,'r--')
plb.subplot(1,2,2)
plt.plot(x,y,'r*-')

# %%
plb.subplot??

# %%
# %matplotlib inline
fig = plt.figure()
#  figure()的作用是独立显示画的图
#  add_axes()的作用是在一个画图面板中包含多个图
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])  # left, bottom, width, height (range 0 to 1
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])
axes1.set_title('main title')
axes1.plot(x,y,'r')
axes1.set_xlabel('x')
axes1.set_ylabel('y')


axes2.set_title('insert title')
axes2.plot(y,x,'g')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# main figure
axes1.plot(x, y, 'r')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
axes1.set_title('title')

# insert
axes2.plot(y, x, 'g')
axes2.set_xlabel('y')
axes2.set_ylabel('x')
axes2.set_title('insert title');

# %%
import matplotlib.pyplot as plt
plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('刘东清', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center',
        color='green', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %%
fig1 = plt.figure()

plt.plot([0.0,1],[0,1],'r')

# %%
plt.bar(left = (0,1),height = (0.5,1))
plt.show()
